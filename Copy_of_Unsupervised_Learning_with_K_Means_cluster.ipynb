# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit-s-s/kmeans/blob/kmeans_latlong/Copy_of_Unsupervised_Learning_with_K_Means_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Important Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading the Dataset

df = pd.read_csv('/content/mch.csv')
df
# Out:
#     sl.no                          Address            City  Lattitude  \
# 0       1                   Railway Colony  Railway Colony   8.488357
# 1       2                       Poojappura       Poojapura   8.491850
# 2       3                          Karumam         Karumam   8.452704
# 3       4       Margin Free Market Karumom        Kaimanam   8.460419
# 4       5                        Pottavila       Pottavila   8.459182
# 5       6              Vinayaka Flour Mill       Vellayani   8.456631
# 6       7                     Pappanamcode    Pappanamcode   8.472386
# 7       8                      Poozhikunnu     Poozhikunnu   8.469754
# 8       9                          Karumam         Karumam   8.452925
# 9      10                        Vellayani       Vellayani   8.446605
# 10     11               Vellayani Junction       Vellayani   8.445939
# 11     12                Viswambharan Road    Pappanamcode   8.468636
# 12     13                      Thiruvallam     Thiruvallam   8.449462
# 13     14                     Sathya nagar        Karamana   8.477214
# 14     15                   Zam zam bakery           Nemom   8.454410
# 15     16                        Kalliyoor       Vellayani   8.432540
# 16     17                            Nemom           Nemom   8.461690
# 17     18          ANU BAKERY & STATIONERY       Vellayani   8.446654
# 18     19                 Medichal College          Ulloor   8.521967
# 19     20  Momi's Margin Free Super Market  Trikkannapuram   8.481691
# 20     21                   Anjana bakery            Nemom   8.446222
# 21     22                 Keerthana Bakery  Pravachambalam   8.449149
# 22     23                Mookambika Sweets    Pappanamcode   8.470002
# 23     24      Vilppana Margin Free Market           Nemom   8.456902
# 24     25                      Satya Nagar    Pappanamcode   8.465780
#
#     Longitude
# 0   76.951268
# 1   76.973882
# 2   76.977354
# 3   76.974185
# 4   76.994198
# 5   76.990867
# 6   76.979356
# 7   76.997900
# 8   76.977348
# 9   76.992286
# 10  76.991854
# 11  76.981899
# 12  76.952129
# 13  76.968208
# 14  76.999865
# 15  77.016672
# 16  76.994304
# 17  76.991862
# 18  76.929611
# 19  77.001221
# 20  76.991791
# 21  77.012586
# 22  76.980894
# 23  77.001348
# 24  76.990154

# %% [markdown]
# **Clusturing**

# %%
x = df.iloc[:,3:5].values

# %%
x
# Out:
# array([[ 8.48835696, 76.95126776],
#        [ 8.49184994, 76.9738824 ],
#        [ 8.45270397, 76.97735425],
#        [ 8.46041885, 76.97418463],
#        [ 8.45918192, 76.9941982 ],
#        [ 8.45663066, 76.99086712],
#        [ 8.47238555, 76.97935642],
#        [ 8.46975378, 76.99789964],
#        [ 8.45292539, 76.97734786],
#        [ 8.44660506, 76.99228617],
#        [ 8.44593899, 76.99185415],
#        [ 8.46863648, 76.98189938],
#        [ 8.44946183, 76.95212892],
#        [ 8.47721448, 76.96820787],
#        [ 8.45441017, 76.99986522],
#        [ 8.43253998, 77.01667245],
#        [ 8.46169008, 76.99430376],
#        [ 8.4466543 , 76.99186185],
#        [ 8.52196742, 76.92961053],
#        [ 8.48169128, 77.00122121],
#        [ 8.44622175, 76.99179072],
#        [ 8.44914896, 77.01258604],
#        [ 8.47000171, 76.98089434],
#        [ 8.45690176, 77.00134822],
#        [ 8.46578026, 76.99015439]])

# %%
# Finding the optimum number of clusters for k-means classification
from sklearn.cluster import KMeans
sse = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++',
                    n_init = 10, random_state = 0)
    kmeans.fit(x)
    sse.append(kmeans.inertia_)

# Plotting the 'The elbow'methord
plt.plot(range(1, 11), sse)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = 6
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(x)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(x[cluster_labels == i][:, 1], x[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of locations')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
cluster_centers
# Out:
# array([[ 8.52196742, 76.92961053],
#        [ 8.45387751, 76.97025392],
#        [ 8.44084447, 77.01462925],
#        [ 8.45156808, 76.99425896],
#        [ 8.46999131, 76.98938988],
#        [ 8.48580713, 76.96445268]])
