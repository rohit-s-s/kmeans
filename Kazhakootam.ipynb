# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit-s-s/kmeans/blob/main/Kazhakootam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Drop-down based on K-means clustering</h1>

# %%
# !pip install veroviz --quiet

# %%
import veroviz as vrv
import pandas as pd

# %%
# # Nodes:
nodesArray = [
    {'id': 0, 'lat': 8.559439966859538, 'lon': 76.90920006362303, 'altMeters': 0.0, 'nodeName': 'gandhipuram', 'nodeType': 'None', 'popupText': 'gandhipuram', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '0', 'elevMeters': None},
    {'id': 1, 'lat': 8.528875727046387, 'lon': 76.91677815583232, 'altMeters': 0.0, 'nodeName': 'prasanth nagar', 'nodeType': 'None', 'popupText': 'prasanth nagar', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '1', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '1', 'elevMeters': None},
    {'id': 2, 'lat': 8.547803974978802, 'lon': 76.91657552192932, 'altMeters': 0.0, 'nodeName': 'sreekaryam', 'nodeType': 'None', 'popupText': 'sreekaryam', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '2', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '2', 'elevMeters': None},
    {'id': 3, 'lat': 8.554049564833619, 'lon': 76.91870586490106, 'altMeters': 0.0, 'nodeName': 'chekkalamukku', 'nodeType': 'None', 'popupText': 'chekkalamukku', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '3', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '3', 'elevMeters': None},
    {'id': 4, 'lat': 8.562857885615923, 'lon': 76.90042668051716, 'altMeters': 0.0, 'nodeName': 'JS Stores Pangapara', 'nodeType': 'None', 'popupText': 'JS Stores Pangapara', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '4', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '4', 'elevMeters': None},
    {'id': 5, 'lat': 8.534228507902883, 'lon': 76.92895710345373, 'altMeters': 0.0, 'nodeName': 'chadrakumar panshop kochullor', 'nodeType': 'None', 'popupText': 'chadrakumar panshop kochullor', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '6', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '6', 'elevMeters': None},
    {'id': 6, 'lat': 8.561966548159836, 'lon': 76.92326373206947, 'altMeters': 0.0, 'nodeName': 'Krishna Bakery', 'nodeType': 'None', 'popupText': 'Krishna Bakery', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 7, 'lat': 8.53780581831055, 'lon': 76.91248572881265, 'altMeters': 0.0, 'nodeName': 'Cheruvikkal', 'nodeType': 'None', 'popupText': 'Cheruvikkal', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '8', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '8', 'elevMeters': None},
    {'id': 8, 'lat': 8.546791329093697, 'lon': 76.91638045187109, 'altMeters': 0.0, 'nodeName': 'Milma Mini supermarket(Vikas nagar)', 'nodeType': 'None', 'popupText': 'Milma Mini supermarket(Vikas nagar)', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '9', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '9', 'elevMeters': None},
    {'id': 9, 'lat': 8.530538055280172, 'lon': 76.92078689585951, 'altMeters': 0.0, 'nodeName': 'Prasanna store', 'nodeType': 'None', 'popupText': 'Prasanna store', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '2', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '2', 'elevMeters': None},
    {'id': 10, 'lat': 8.559148953348778, 'lon': 76.89800102925045, 'altMeters': 0.0, 'nodeName': 'Pangapara', 'nodeType': 'None', 'popupText': 'Pangapara', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '3', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '3', 'elevMeters': None},
    {'id': 11, 'lat': 8.53353861325879, 'lon': 76.92266693784279, 'altMeters': 0.0, 'nodeName': 'Priyadarshini nagar', 'nodeType': 'None', 'popupText': 'Priyadarshini nagar', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 12, 'lat':8.533353555768477, 'lon': 76.92906312274451, 'altMeters': 0.0, 'nodeName': 'Ullor', 'nodeType': 'None', 'popupText': 'Ullor', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 13, 'lat':  8.55229294866185, 'lon': 76.90784024373504, 'altMeters': 0.0, 'nodeName': 'Danya Supermarket', 'nodeType': 'None', 'popupText': 'Danya Supermarket', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 14, 'lat':8.521772798305816, 'lon':76.91325407290314, 'altMeters': 0.0, 'nodeName': 'govt care puliyarakottah', 'nodeType': 'None', 'popupText': 'govt care puliyarakottah', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 15, 'lat': 8.529350415410152, 'lon': 76.91216555538024, 'altMeters': 0.0, 'nodeName': 'Aditya storet', 'nodeType': 'None', 'popupText': 'Aditya storet', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 16, 'lat': 8.5304234147535, 'lon': 76.91251194003772, 'altMeters': 0.0, 'nodeName': 'Sobhas Mini Supermarket', 'nodeType': 'None', 'popupText': 'Sobhas Mini Supermarket', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},

]
myNodes = pd.DataFrame(nodesArray)

# %%
# Define a center point for customers.  The geocode() function returns [lat, lon] coordinates.
geoCenter = [8.543664387156574,76.91519350400599]

# Define a radius for 1 standard deviation, in units of meters.
radiusMeters = vrv.convertDistance(2, 'miles', 'meters')

# %%
# Draw the customer region with circles, and label according to standard deviation:

myMap = vrv.addLeafletText(text        = 'Kazhakootam Region',
                           fontColor   = 'black',
                           anchorPoint = vrv.pointInDistance2D(geoCenter, 90, radiusMeters))
myMap = vrv.addLeafletCircle(mapObject = myMap,
                             center    = geoCenter,
                             radius    = 1*radiusMeters,
                             fillColor = 'blue')

# %%
# Add nodes to the previously-created map:
vrv.createLeaflet(mapObject = myMap,
                  nodes     = myNodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import numpy as np
locations = np.array([
    [8.559439966859538, 76.90920006362303],
    [8.528875727046387, 76.91677815583232],
    [8.547803974978802, 76.91657552192932],
    [8.554049564833619, 76.91870586490106],
    [8.562857885615923, 76.90042668051716],
    [8.534228507902883, 76.92895710345373],
    [8.561966548159836, 76.92326373206947],
    [8.53780581831055, 76.91248572881265],
    [8.546791329093697, 76.91638045187109],
    [8.530538055280172, 76.92078689585951],
    [8.559148953348778, 76.89800102925045],
    [8.53353861325879, 76.92266693784279],
    [8.533353555768477, 76.92906312274451],
    [8.55229294866185, 76.90784024373504],
    [8.521772798305816, 76.91325407290314],
    [8.529350415410152, 76.91216555538024],
    [8.5304234147535, 76.91251194003772],
    # Add more data points here
])

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = 3  # You can adjust this based on your needs
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(locations)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(locations[cluster_labels == i][:, 1], locations[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of Locations')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Nodes:
nodesArray = [
    {'id': 1, 'lat': 8.528875727046387, 'lon': 76.91677815583232, 'altMeters': 0.0, 'nodeName': 'prasanth nagar', 'nodeType': 'None', 'popupText': 'prasanth nagar', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'orange', 'leafletIconText': '1', 'cesiumIconType': 'pin', 'cesiumColor': 'orange', 'cesiumIconText': '1', 'elevMeters': None},
    {'id': 2, 'lat': 8.534228507902883, 'lon': 76.92895710345373, 'altMeters': 0.0, 'nodeName': 'chadrakumar panshop kochullor', 'nodeType': 'None', 'popupText': 'chadrakumar panshop kochullor', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'orange', 'leafletIconText': '6', 'cesiumIconType': 'pin', 'cesiumColor': 'orange', 'cesiumIconText': '6', 'elevMeters': None},
    {'id': 3, 'lat': 8.53780581831055, 'lon': 76.91248572881265, 'altMeters': 0.0, 'nodeName': 'Cheruvikkal', 'nodeType': 'None', 'popupText': 'Cheruvikkal', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'orange', 'leafletIconText': '8', 'cesiumIconType': 'pin', 'cesiumColor': 'orange', 'cesiumIconText': '8', 'elevMeters': None},
    {'id': 4, 'lat': 8.530538055280172, 'lon': 76.92078689585951, 'altMeters': 0.0, 'nodeName': 'Prasanna store', 'nodeType': 'None', 'popupText': 'Prasanna store', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'orange', 'leafletIconText': '2', 'cesiumIconType': 'pin', 'cesiumColor': 'orange', 'cesiumIconText': '2', 'elevMeters': None},
    {'id': 5, 'lat': 8.53353861325879, 'lon': 76.92266693784279, 'altMeters': 0.0, 'nodeName': 'Priyadarshini nagar', 'nodeType': 'None', 'popupText': 'Priyadarshini nagar', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'orange', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'orange', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 6, 'lat':8.533353555768477, 'lon': 76.92906312274451, 'altMeters': 0.0, 'nodeName': 'Ullor', 'nodeType': 'None', 'popupText': 'Ullor', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'orange', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'orange', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 7, 'lat':8.521772798305816, 'lon':76.91325407290314, 'altMeters': 0.0, 'nodeName': 'govt care puliyarakottah', 'nodeType': 'None', 'popupText': 'govt care puliyarakottah', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'orange', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'orange', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 8, 'lat': 8.529350415410152, 'lon': 76.91216555538024, 'altMeters': 0.0, 'nodeName': 'Aditya storet', 'nodeType': 'None', 'popupText': 'Aditya storet', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'orange', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'orange', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 9, 'lat': 8.5304234147535, 'lon': 76.91251194003772, 'altMeters': 0.0, 'nodeName': 'Sobhas Mini Supermarket', 'nodeType': 'None', 'popupText': 'Sobhas Mini Supermarket', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'orange', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'orange', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 10, 'lat': 8.547803974978802, 'lon': 76.91657552192932, 'altMeters': 0.0, 'nodeName': 'sreekaryam', 'nodeType': 'None', 'popupText': 'sreekaryam', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'green', 'leafletIconText': '2', 'cesiumIconType': 'pin', 'cesiumColor': 'green', 'cesiumIconText': '2', 'elevMeters': None},
    {'id': 12, 'lat': 8.554049564833619, 'lon': 76.91870586490106, 'altMeters': 0.0, 'nodeName': 'chekkalamukku', 'nodeType': 'None', 'popupText': 'chekkalamukku', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'green', 'leafletIconText': '3', 'cesiumIconType': 'pin', 'cesiumColor': 'green', 'cesiumIconText': '3', 'elevMeters': None},
    {'id': 13, 'lat': 8.561966548159836, 'lon': 76.92326373206947, 'altMeters': 0.0, 'nodeName': 'Krishna Bakery', 'nodeType': 'None', 'popupText': 'Krishna Bakery', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'green', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'green', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 14, 'lat': 8.546791329093697, 'lon': 76.91638045187109, 'altMeters': 0.0, 'nodeName': 'Milma Mini supermarket(Vikas nagar)', 'nodeType': 'None', 'popupText': 'Milma Mini supermarket(Vikas nagar)', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'green', 'leafletIconText': '9', 'cesiumIconType': 'pin', 'cesiumColor': 'green', 'cesiumIconText': '9', 'elevMeters': None},
    {'id': 11, 'lat': 8.562857885615923, 'lon': 76.90042668051716, 'altMeters': 0.0, 'nodeName': 'JS Stores Pangapara', 'nodeType': 'None', 'popupText': 'JS Stores Pangapara', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '4', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '4', 'elevMeters': None},
    {'id': 15, 'lat': 8.559148953348778, 'lon': 76.89800102925045, 'altMeters': 0.0, 'nodeName': 'Pangapara', 'nodeType': 'None', 'popupText': 'Pangapara', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '3', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '3', 'elevMeters': None},
    {'id': 16, 'lat':  8.55229294866185, 'lon': 76.90784024373504, 'altMeters': 0.0, 'nodeName': 'Danya Supermarket', 'nodeType': 'None', 'popupText': 'Danya Supermarket', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 17, 'lat': 8.559439966859538, 'lon': 76.90920006362303, 'altMeters': 0.0, 'nodeName': 'gandhipuram', 'nodeType': 'None', 'popupText': 'gandhipuram', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '0', 'elevMeters': None},
    {'id': 18, 'lat': 8.558435, 'lon': 76.90387, 'altMeters': 0.0, 'nodeName': 'cluster1', 'nodeType': 'None', 'popupText': 'cluster1', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'red', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'red', 'cesiumIconText': '0', 'elevMeters': None},
    {'id': 19, 'lat': 8.552653, 'lon':76.91873, 'altMeters': 0.0, 'nodeName': 'cluster2', 'nodeType': 'None', 'popupText': 'cluster2', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'red', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'red', 'cesiumIconText': '0', 'elevMeters': None},
    {'id': 20, 'lat': 8.531099, 'lon': 76.91874,  'altMeters': 0.0, 'nodeName': 'cluster3', 'nodeType': 'None', 'popupText': 'cluster3', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'red', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'red', 'cesiumIconText': '0', 'elevMeters': None},
]

myNodes = pd.DataFrame(nodesArray)

# %%
vrv.createLeaflet(mapObject = myMap,
                  nodes     = myNodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
    # Nodes:
nodesArray = [
    {'id': 0, 'lat': 8.558435, 'lon': 76.90387, 'altMeters': 0.0, 'nodeName': 'cluster1', 'nodeType': 'None', 'popupText': 'cluster1', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'red', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'red', 'cesiumIconText': '0', 'elevMeters': None},
    {'id': 1, 'lat': 8.552653, 'lon':76.91873, 'altMeters': 0.0, 'nodeName': 'cluster2', 'nodeType': 'None', 'popupText': 'cluster2', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'red', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'red', 'cesiumIconText': '0', 'elevMeters': None},
    {'id': 2, 'lat': 8.531099, 'lon': 76.91874,  'altMeters': 0.0, 'nodeName': 'cluster3', 'nodeType': 'None', 'popupText': 'cluster3', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'red', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'red', 'cesiumIconText': '0', 'elevMeters': None},
    ]
myNodes = pd.DataFrame(nodesArray)
# Arcs/Routes:
arcsArray = [
    {'odID': 0, 'objectID': "Truck",'startLat': 8.558435, 'startLon': 76.90387, 'endLat':8.552653, 'endLon': 76.91873, 'leafletColor': 'orange', 'leafletWeight': 5, 'leafletStyle': 'solid', 'leafletOpacity': 0.8, 'leafletCurveType': 'straight', 'leafletCurvature': 0, 'useArrows': True, 'cesiumColor': 'orange', 'cesiumWeight': 5, 'cesiumStyle': 'solid', 'cesiumOpacity': 0.8, 'popupText': None,'startElevMeters': None,'endElevMeters': None},
    {'odID': 1, 'objectID': "Truck",'startLat': 8.552653, 'startLon': 76.91873, 'endLat': 8.531099, 'endLon':76.91874, 'leafletColor': 'orange', 'leafletWeight': 5, 'leafletStyle': 'solid', 'leafletOpacity': 0.8, 'leafletCurveType': 'straight', 'leafletCurvature': 0, 'useArrows': True, 'cesiumColor': 'orange', 'cesiumWeight': 5, 'cesiumStyle': 'solid', 'cesiumOpacity': 0.8, 'popupText': None,'startElevMeters': None,'endElevMeters': None},
   ]
myArcs = pd.DataFrame(arcsArray)

# %%
# Turn-by-turn road network travel for the truck:
myAssignments = vrv.createAssignmentsFromArcs2D(
        arcs             = myArcs[myArcs['objectID'] == 'Truck'],
        modelFile        = 'veroviz/models/ub_truck.gltf',
        routeType        = 'fastest',
        dataProvider     = 'OSRM-online',
        serviceTimeSec   = 30
        )
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assignments = assignments.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assignments = assignments.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   assignments = assignments.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
myMap = vrv.addLeafletCircle(center    = geoCenter,
                             radius    = 1*radiusMeters,
                             fillColor = 'blue')
vrv.createLeaflet(nodes = myNodes,
                  mapObject = myMap,
                  arcs  = myAssignments)
                  # boundingRegion=myBoundary
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:48: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# ...
