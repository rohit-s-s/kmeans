# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit-s-s/kmeans/blob/main/Kazhakootam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install veroviz --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 31.6 MB/s eta 0:00:00

# %%
import veroviz as vrv
import pandas as pd

# %%
# # Nodes:
nodesArray = [
    {'id': 0, 'lat': 8.559439966859538, 'lon': 76.90920006362303, 'altMeters': 0.0, 'nodeName': 'gandhipuram', 'nodeType': 'None', 'popupText': 'gandhipuram', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '0', 'elevMeters': None},
    {'id': 1, 'lat': 8.528875727046387, 'lon': 76.91677815583232, 'altMeters': 0.0, 'nodeName': 'prasanth nagar', 'nodeType': 'None', 'popupText': 'prasanth nagar', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '1', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '1', 'elevMeters': None},
    {'id': 2, 'lat': 8.547803974978802, 'lon': 76.91657552192932, 'altMeters': 0.0, 'nodeName': 'sreekaryam', 'nodeType': 'None', 'popupText': 'sreekaryam', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '2', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '2', 'elevMeters': None},
    {'id': 3, 'lat': 8.554049564833619, 'lon': 76.91870586490106, 'altMeters': 0.0, 'nodeName': 'chekkalamukku', 'nodeType': 'None', 'popupText': 'chekkalamukku', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '3', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '3', 'elevMeters': None},
    {'id': 4, 'lat': 8.562857885615923, 'lon': 76.90042668051716, 'altMeters': 0.0, 'nodeName': 'JS Stores Pangapara', 'nodeType': 'None', 'popupText': 'JS Stores Pangapara', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '4', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '4', 'elevMeters': None},
    {'id': 5, 'lat': 8.534228507902883, 'lon': 76.92895710345373, 'altMeters': 0.0, 'nodeName': 'chadrakumar panshop kochullor', 'nodeType': 'None', 'popupText': 'chadrakumar panshop kochullor', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '6', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '6', 'elevMeters': None},
    {'id': 6, 'lat': 8.561966548159836, 'lon': 76.92326373206947, 'altMeters': 0.0, 'nodeName': 'Krishna Bakery', 'nodeType': 'None', 'popupText': 'Krishna Bakery', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 7, 'lat': 8.53780581831055, 'lon': 76.91248572881265, 'altMeters': 0.0, 'nodeName': 'Cheruvikkal', 'nodeType': 'None', 'popupText': 'Cheruvikkal', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '8', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '8', 'elevMeters': None},
    {'id': 8, 'lat': 8.546791329093697, 'lon': 76.91638045187109, 'altMeters': 0.0, 'nodeName': 'Milma Mini supermarket(Vikas nagar)', 'nodeType': 'None', 'popupText': 'Milma Mini supermarket(Vikas nagar)', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '9', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '9', 'elevMeters': None},
    {'id': 9, 'lat': 8.530538055280172, 'lon': 76.92078689585951, 'altMeters': 0.0, 'nodeName': 'Prasanna store', 'nodeType': 'None', 'popupText': 'Prasanna store', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '2', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '2', 'elevMeters': None},
    {'id': 10, 'lat': 8.559148953348778, 'lon': 76.89800102925045, 'altMeters': 0.0, 'nodeName': 'Pangapara', 'nodeType': 'None', 'popupText': 'Pangapara', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '3', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '3', 'elevMeters': None},
    {'id': 11, 'lat': 8.53353861325879, 'lon': 76.92266693784279, 'altMeters': 0.0, 'nodeName': 'Priyadarshini nagar', 'nodeType': 'None', 'popupText': 'Priyadarshini nagar', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 12, 'lat':8.533353555768477, 'lon': 76.92906312274451, 'altMeters': 0.0, 'nodeName': 'Ullor', 'nodeType': 'None', 'popupText': 'Ullor', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 13, 'lat':  8.55229294866185, 'lon': 76.90784024373504, 'altMeters': 0.0, 'nodeName': 'Danya Supermarket', 'nodeType': 'None', 'popupText': 'Danya Supermarket', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 14, 'lat':8.521772798305816, 'lon':76.91325407290314, 'altMeters': 0.0, 'nodeName': 'govt care puliyarakottah', 'nodeType': 'None', 'popupText': 'govt care puliyarakottah', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 15, 'lat': 8.529350415410152, 'lon': 76.91216555538024, 'altMeters': 0.0, 'nodeName': 'Aditya storet', 'nodeType': 'None', 'popupText': 'Aditya storet', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 16, 'lat': 8.5304234147535, 'lon': 76.91251194003772, 'altMeters': 0.0, 'nodeName': 'Sobhas Mini Supermarket', 'nodeType': 'None', 'popupText': 'Sobhas Mini Supermarket', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 17, 'lat':  8.543664387156574, 'lon':  76.91519350400599, 'altMeters': 0.0, 'nodeName': 'Center', 'nodeType': 'None', 'popupText': 'Center', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'green', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},

]
myNodes = pd.DataFrame(nodesArray)

# %%
# Define a center point for customers.  The geocode() function returns [lat, lon] coordinates.
geoCenter = [8.543664387156574,76.91519350400599]

# Define a radius for 1 standard deviation, in units of meters.
radiusMeters = vrv.convertDistance(2, 'miles', 'meters')

# %%
myMap = vrv.addLeafletText(text        = 'Depot Region',
                           fontColor   = 'black',)

# Draw the customer region with circles, and label according to standard deviation:

myMap = vrv.addLeafletText(mapObject   = myMap,
                           text        = '1 std. dev.',
                           fontColor   = 'black',
                           anchorPoint = vrv.pointInDistance2D(geoCenter, 180, radiusMeters))
myMap = vrv.addLeafletCircle(mapObject = myMap,
                             center    = geoCenter,
                             radius    = 1*radiusMeters,
                             fillColor = 'blue')
# Out:
# Error: `loc` should not be None.

# %%
# Add nodes to the previously-created map:
vrv.createLeaflet(mapObject = myMap,
                  nodes     = myNodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Nodes:
nodesArray = [
    {'id': 0, 'lat':  8.543664387156574, 'lon':  76.91519350400599, 'altMeters': 0.0, 'nodeName': 'Center', 'nodeType': 'None', 'popupText': 'Center', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'green', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 1, 'lat': 8.528875727046387, 'lon': 76.91677815583232, 'altMeters': 0.0, 'nodeName': 'prasanth nagar', 'nodeType': 'None', 'popupText': 'prasanth nagar', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '1', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '1', 'elevMeters': None},
    {'id': 2, 'lat': 8.547803974978802, 'lon': 76.91657552192932, 'altMeters': 0.0, 'nodeName': 'sreekaryam', 'nodeType': 'None', 'popupText': 'sreekaryam', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '2', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '2', 'elevMeters': None},
    {'id': 3, 'lat': 8.554049564833619, 'lon': 76.91870586490106, 'altMeters': 0.0, 'nodeName': 'chekkalamukku', 'nodeType': 'None', 'popupText': 'chekkalamukku', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '3', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '3', 'elevMeters': None},
    {'id': 4, 'lat': 8.562857885615923, 'lon': 76.90042668051716, 'altMeters': 0.0, 'nodeName': 'JS Stores Pangapara', 'nodeType': 'None', 'popupText': 'JS Stores Pangapara', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '4', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '4', 'elevMeters': None},
    {'id': 6, 'lat': 8.534228507902883, 'lon': 76.92895710345373, 'altMeters': 0.0, 'nodeName': 'chadrakumar panshop kochullor', 'nodeType': 'None', 'popupText': 'chadrakumar panshop kochullor', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '6', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '6', 'elevMeters': None},
    {'id': 7, 'lat': 8.561966548159836, 'lon': 76.92326373206947, 'altMeters': 0.0, 'nodeName': 'Krishna Bakery', 'nodeType': 'None', 'popupText': 'Krishna Bakery', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 8, 'lat': 8.53780581831055, 'lon': 76.91248572881265, 'altMeters': 0.0, 'nodeName': 'Cheruvikkal', 'nodeType': 'None', 'popupText': 'Cheruvikkal', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '8', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '8', 'elevMeters': None},
    {'id': 10, 'lat': 8.546791329093697, 'lon': 76.91638045187109, 'altMeters': 0.0, 'nodeName': 'Milma Mini supermarket(Vikas nagar)', 'nodeType': 'None', 'popupText': 'Milma Mini supermarket(Vikas nagar)', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '9', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '9', 'elevMeters': None},
    {'id': 12, 'lat': 8.530538055280172, 'lon': 76.92078689585951, 'altMeters': 0.0, 'nodeName': 'Prasanna store', 'nodeType': 'None', 'popupText': 'Prasanna store', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '2', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '2', 'elevMeters': None},
    {'id': 13, 'lat': 8.559148953348778, 'lon': 76.89800102925045, 'altMeters': 0.0, 'nodeName': 'Pangapara', 'nodeType': 'None', 'popupText': 'Pangapara', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '3', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '3', 'elevMeters': None},
    {'id': 14, 'lat': 8.53353861325879, 'lon': 76.92266693784279, 'altMeters': 0.0, 'nodeName': 'Priyadarshini nagar', 'nodeType': 'None', 'popupText': 'Priyadarshini nagar', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 15, 'lat':8.533353555768477, 'lon': 76.92906312274451, 'altMeters': 0.0, 'nodeName': 'Ullor', 'nodeType': 'None', 'popupText': 'Ullor', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 16, 'lat':  8.55229294866185, 'lon': 76.90784024373504, 'altMeters': 0.0, 'nodeName': 'Danya Supermarket', 'nodeType': 'None', 'popupText': 'Danya Supermarket', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 17, 'lat':8.521772798305816, 'lon':76.91325407290314, 'altMeters': 0.0, 'nodeName': 'govt care puliyarakottah', 'nodeType': 'None', 'popupText': 'govt care puliyarakottah', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 20, 'lat': 8.529350415410152, 'lon': 76.91216555538024, 'altMeters': 0.0, 'nodeName': 'Aditya storet', 'nodeType': 'None', 'popupText': 'Aditya storet', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 21, 'lat': 8.5304234147535, 'lon': 76.91251194003772, 'altMeters': 0.0, 'nodeName': 'Sobhas Mini Supermarket', 'nodeType': 'None', 'popupText': 'Sobhas Mini Supermarket', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 22, 'lat': 8.559439966859538, 'lon': 76.90920006362303, 'altMeters': 0.0, 'nodeName': 'gandhipuram', 'nodeType': 'None', 'popupText': 'gandhipuram', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '0', 'elevMeters': None},
]
myNodes = pd.DataFrame(nodesArray)

# %%
[time, dist] = vrv.getTimeDist2D(nodes        = myNodes,
                                 matrixType   = 'all2all',
                                 routeType    = 'fastest',
                                 dataProvider = 'OSRM-online')

# %%
myNodes
# Out:
#     id       lat        lon  altMeters                             nodeName  \
# 0    0  8.543664  76.915194        0.0                               Center
# 1    1  8.528876  76.916778        0.0                       prasanth nagar
# 2    2  8.547804  76.916576        0.0                           sreekaryam
# 3    3  8.554050  76.918706        0.0                        chekkalamukku
# 4    4  8.562858  76.900427        0.0                  JS Stores Pangapara
# 5    6  8.534229  76.928957        0.0        chadrakumar panshop kochullor
# 6    7  8.561967  76.923264        0.0                       Krishna Bakery
# 7    8  8.537806  76.912486        0.0                          Cheruvikkal
# 8   10  8.546791  76.916380        0.0  Milma Mini supermarket(Vikas nagar)
# 9   12  8.530538  76.920787        0.0                       Prasanna store
# 10  13  8.559149  76.898001        0.0                            Pangapara
# ...

# %%
dist_Meter = vrv.convertMatricesDictionaryToDataframe(dist)

# %%
dist_Meter
# Out:
#         0       1       2       3       4       6       7       8       10  \
# 0      0.0  2159.8   641.5  1461.0  3586.4  3082.3  2707.7   822.0   523.1
# 1   2159.8     0.0  2638.7  3458.2  5583.5  2154.9  4704.8  1382.4  2520.3
# 2    641.5  2638.7     0.0   819.5  2944.8  2440.8  2066.1  1300.8   118.4
# 3   1461.0  3458.2   819.5     0.0  3496.5  2992.5  1369.3  2120.3   937.9
# 4   3586.4  5583.5  2944.8  3496.5     0.0  5117.8  4743.1  4245.6  3063.2
# 6   2692.8  2467.4  2583.7  3135.4  5260.7     0.0  4382.0  3237.9  2702.1
# 7   2707.7  4704.8  2066.1  1369.3  4028.9  4239.1     0.0  3366.9  2184.5
# 8    822.0  1382.4  1300.8  2120.3  4245.6  3095.0  3366.9     0.0  1182.4
# 10   523.1  2520.3   118.4   937.9  3063.2  2559.2  2184.5  1182.4     0.0
# 12  2532.5   821.0  2850.4  3402.1  5527.4  2184.4  4648.7  1755.1  2968.8
# 13  3584.8  5582.0  2943.3  3495.0   876.1  5116.3  4741.6  4244.1  3061.7
# ...

# %%
route = {}

# %%
truckNodes = myNodes

# Solve TSP using a simple nearest-neighbors heuristic
startNode = 0  # depot
route['truck'] = [startNode]
while (len(route['truck']) < len(truckNodes)):
    closestNode = vrv.nearestNodes(
        nodes=truckNodes[~truckNodes['id'].isin(route['truck'][0:-1])],
        origin=route['truck'][-1],
        costDict=dist,
        k=1
    )['id'].values[0]
    route['truck'].append(closestNode)

# Return to depot
route['truck'].append(startNode)
node_path = route['truck']
print(node_path)
# Out:
# [0, 10, 2, 3, 7, 16, 22, 4, 13, 8, 21, 20, 1, 12, 14, 15, 6, 17, 0]

# %%
total_distance_traveled = 0

# Iterate through the node path to calculate distances
for i in range(len(node_path) - 1):
    from_node = node_path[i]
    to_node = node_path[i + 1]
    distance = dist_Meter[from_node][to_node]
    total_distance_traveled += distance

distanceKilometers = vrv.convertDistance(total_distance_traveled, 'm', 'km')
distanceKilometers
# Out:
# 24.001600000000003

# %%
# Convert the truck's route to an "arcs" dataframe:
myArcs = vrv.createArcsFromNodeSeq(nodeSeq  = route['truck'],
                                   nodes    = myNodes,
                                   objectID = 'Truck')
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# ...

# %%
# Turn-by-turn road network travel for the truck:
myAssignments = vrv.createAssignmentsFromArcs2D(
        arcs             = myArcs[myArcs['objectID'] == 'Truck'],
        modelFile        = 'veroviz/models/ub_truck.gltf',
        routeType        = 'fastest',
        dataProvider     = 'OSRM-online',
        serviceTimeSec   = 30,
        ganttColor       = 'orange')
# Out:
# Message: The origin point (lat: 8.543664387156573, lon: 76.91519350400598) is 45.9 meters away from the road. You might find a gap between the origin point and the route.
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assignments = assignments.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assignments = assignments.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   assignments = assignments.append({
# ...

# %%
myMap = vrv.addLeafletText(mapObject   = myMap,
                           text        = distanceKilometers,
                           fontColor   = 'black',
                           anchorPoint = myBoundingRegion[3])

# %%
vrv.createLeaflet(nodes = myNodes,
                  mapObject = myMap,
                  arcs  = myAssignments)
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:48: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
# ...

# %%
map = vrv.createLeaflet(nodes = myNodes,
                  mapObject = myMap,
                  arcs  = myAssignments)
map.save('poojapura.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:48: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
# ...

# %%
locations = np.array([
    [8.559439966859538, 76.90920006362303],
    [8.528875727046387, 76.91677815583232],
    [8.547803974978802, 76.91657552192932],
    [8.554049564833619, 76.91870586490106],
    [8.562857885615923, 76.90042668051716],
    [8.534228507902883, 76.92895710345373],
    [8.561966548159836, 76.92326373206947],
    [8.53780581831055, 76.91248572881265],
    [8.546791329093697, 76.91638045187109],
    [8.530538055280172, 76.92078689585951],
    [8.559148953348778, 76.89800102925045],
    [8.53353861325879, 76.92266693784279],
    [8.533353555768477, 76.92906312274451],
    [8.55229294866185, 76.90784024373504],
    [8.521772798305816, 76.91325407290314],
    [8.529350415410152, 76.91216555538024],
    [8.5304234147535, 76.91251194003772],
    # Add more data points here
])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = 3  # You can adjust this based on your needs
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(locations)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(locations[cluster_labels == i][:, 1], locations[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of Locations')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Nodes:
nodesArray = [
    {'id': 0, 'lat':  8.543664387156574, 'lon':  76.91519350400599, 'altMeters': 0.0, 'nodeName': 'Center', 'nodeType': 'None', 'popupText': 'Center', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'green', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 1, 'lat': 8.562857885615923, 'lon': 76.90042668051716, 'altMeters': 0.0, 'nodeName': 'JS Stores Pangapara', 'nodeType': 'None', 'popupText': 'JS Stores Pangapara', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '4', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '4', 'elevMeters': None},
    {'id': 2, 'lat': 8.559148953348778, 'lon': 76.89800102925045, 'altMeters': 0.0, 'nodeName': 'Pangapara', 'nodeType': 'None', 'popupText': 'Pangapara', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '3', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '3', 'elevMeters': None},
    {'id': 3, 'lat':  8.55229294866185, 'lon': 76.90784024373504, 'altMeters': 0.0, 'nodeName': 'Danya Supermarket', 'nodeType': 'None', 'popupText': 'Danya Supermarket', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 4, 'lat': 8.559439966859538, 'lon': 76.90920006362303, 'altMeters': 0.0, 'nodeName': 'gandhipuram', 'nodeType': 'None', 'popupText': 'gandhipuram', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '0', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '0', 'elevMeters': None},
]
myNodes = pd.DataFrame(nodesArray)

# %%
[time, dist] = vrv.getTimeDist2D(nodes        = myNodes,
                                 matrixType   = 'all2all',
                                 routeType    = 'fastest',
                                 dataProvider = 'OSRM-online')

# %%
route = {}
truckNodes = myNodes

# Solve TSP using a simple nearest-neighbors heuristic
startNode = 0  # depot
route['truck'] = [startNode]
while (len(route['truck']) < len(truckNodes)):
    closestNode = vrv.nearestNodes(
        nodes=truckNodes[~truckNodes['id'].isin(route['truck'][0:-1])],
        origin=route['truck'][-1],
        costDict=dist,
        k=1
    )['id'].values[0]
    route['truck'].append(closestNode)

# Return to depot
route['truck'].append(startNode)
node_path = route['truck']
print(node_path)
# Out:
# [0, 3, 4, 1, 2, 0]

# %%
dist_Meter = vrv.convertMatricesDictionaryToDataframe(dist)

# %%
total_distance_traveled = 0

# Iterate through the node path to calculate distances
for i in range(len(node_path) - 1):
    from_node = node_path[i]
    to_node = node_path[i + 1]
    distance = dist_Meter[from_node][to_node]
    total_distance_traveled += distance

distanceKilometers = vrv.convertDistance(total_distance_traveled, 'm', 'km')
distanceKilometers
# Out:
# 8.998

# %%
# Convert the truck's route to an "arcs" dataframe:
myArcs = vrv.createArcsFromNodeSeq(nodeSeq  = route['truck'],
                                   nodes    = myNodes,
                                   objectID = 'Truck')
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# ...

# %%
# Turn-by-turn road network travel for the truck:
myAssignments = vrv.createAssignmentsFromArcs2D(
        arcs             = myArcs[myArcs['objectID'] == 'Truck'],
        modelFile        = 'veroviz/models/ub_truck.gltf',
        routeType        = 'fastest',
        dataProvider     = 'OSRM-online',
        serviceTimeSec   = 30,
        ganttColor       = 'orange')
# Out:
# Message: The origin point (lat: 8.543664387156573, lon: 76.91519350400598) is 45.9 meters away from the road. You might find a gap between the origin point and the route.
# Message: The destination point (lat: 8.55229294866185, lon: 76.90784024373504) is 14.2 meters away from the road. You might find a gap between destination point and the route.
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assignments = assignments.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assignments = assignments.append({
# ...

# %%
myMap = vrv.addLeafletText(
                           text        = distanceKilometers,
                           fontColor   = 'black',
                           anchorPoint = myBoundingRegion[3])

# %%
vrv.createLeaflet(nodes = myNodes,
                  mapObject = myMap,
                  arcs  = myAssignments)
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:48: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
# ...

# %%
# Nodes:
nodesArray = [
    {'id': 0, 'lat':  8.543664387156574, 'lon':  76.91519350400599, 'altMeters': 0.0, 'nodeName': 'Center', 'nodeType': 'None', 'popupText': 'Center', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'green', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
   {'id': 1, 'lat': 8.547803974978802, 'lon': 76.91657552192932, 'altMeters': 0.0, 'nodeName': 'sreekaryam', 'nodeType': 'None', 'popupText': 'sreekaryam', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '2', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '2', 'elevMeters': None},
    {'id': 2, 'lat': 8.554049564833619, 'lon': 76.91870586490106, 'altMeters': 0.0, 'nodeName': 'chekkalamukku', 'nodeType': 'None', 'popupText': 'chekkalamukku', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '3', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '3', 'elevMeters': None},
    {'id': 3, 'lat': 8.561966548159836, 'lon': 76.92326373206947, 'altMeters': 0.0, 'nodeName': 'Krishna Bakery', 'nodeType': 'None', 'popupText': 'Krishna Bakery', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 4, 'lat': 8.546791329093697, 'lon': 76.91638045187109, 'altMeters': 0.0, 'nodeName': 'Milma Mini supermarket(Vikas nagar)', 'nodeType': 'None', 'popupText': 'Milma Mini supermarket(Vikas nagar)', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '9', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '9', 'elevMeters': None},
]
myNodes = pd.DataFrame(nodesArray)

# %%
myNodes
# Out:
#    id       lat        lon  altMeters                             nodeName  \
# 0   0  8.543664  76.915194        0.0                               Center
# 1   1  8.547804  76.916576        0.0                           sreekaryam
# 2   2  8.554050  76.918706        0.0                        chekkalamukku
# 3   3  8.561967  76.923264        0.0                       Krishna Bakery
# 4   4  8.546791  76.916380        0.0  Milma Mini supermarket(Vikas nagar)
#
#   nodeType                            popupText leafletIconPrefix  \
# 0     None                               Center         glyphicon
# 1     None                           sreekaryam         glyphicon
# 2     None                        chekkalamukku         glyphicon
# 3     None                       Krishna Bakery         glyphicon
# 4     None  Milma Mini supermarket(Vikas nagar)         glyphicon
#
#   leafletIconType leafletColor leafletIconText cesiumIconType cesiumColor  \
# ...

# %%
[time, dist] = vrv.getTimeDist2D(nodes        = myNodes,
                                 matrixType   = 'all2all',
                                 routeType    = 'fastest',
                                 dataProvider = 'OSRM-online')

# %%
route = {}
truckNodes = myNodes

# Solve TSP using a simple nearest-neighbors heuristic
startNode = 0  # depot
route['truck'] = [startNode]
while (len(route['truck']) < len(truckNodes)):
    closestNode = vrv.nearestNodes(
        nodes=truckNodes[~truckNodes['id'].isin(route['truck'][0:-1])],
        origin=route['truck'][-1],
        costDict=dist,
        k=1
    )['id'].values[0]
    route['truck'].append(closestNode)

# Return to depot
route['truck'].append(startNode)
node_path = route['truck']
print(node_path)
# Out:
# [0, 4, 1, 2, 3, 0]

# %%
dist_Meter = vrv.convertMatricesDictionaryToDataframe(dist)

# %%
total_distance_traveled = 0

# Iterate through the node path to calculate distances
for i in range(len(node_path) - 1):
    from_node = node_path[i]
    to_node = node_path[i + 1]
    distance = dist_Meter[from_node][to_node]
    total_distance_traveled += distance

distanceKilometers = vrv.convertDistance(total_distance_traveled, 'm', 'km')
distanceKilometers
# Out:
# 5.538

# %%
# Convert the truck's route to an "arcs" dataframe:
myArcs = vrv.createArcsFromNodeSeq(nodeSeq  = route['truck'],
                                   nodes    = myNodes,
                                   objectID = 'Truck')
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# ...

# %%
# Turn-by-turn road network travel for the truck:
myAssignments = vrv.createAssignmentsFromArcs2D(
        arcs             = myArcs[myArcs['objectID'] == 'Truck'],
        modelFile        = 'veroviz/models/ub_truck.gltf',
        routeType        = 'fastest',
        dataProvider     = 'OSRM-online',
        serviceTimeSec   = 30,
        ganttColor       = 'yellow')
# Out:
# Message: The origin point (lat: 8.543664387156573, lon: 76.91519350400598) is 45.9 meters away from the road. You might find a gap between the origin point and the route.
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assignments = assignments.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assignments = assignments.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   assignments = assignments.append({
# ...

# %%
myMap = vrv.addLeafletText(text        = distanceKilometers,
                           fontColor   = 'black',
                           anchorPoint = myBoundingRegion[3])

# %%
vrv.createLeaflet(nodes = myNodes,
                  mapObject = myMap,
                  arcs  = myAssignments)
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:48: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
# ...

# %%
# Nodes:
nodesArray = [
    {'id': 0, 'lat':  8.543664387156574, 'lon':  76.91519350400599, 'altMeters': 0.0, 'nodeName': 'Center', 'nodeType': 'None', 'popupText': 'Center', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'home', 'leafletColor': 'green', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 1, 'lat': 8.528875727046387, 'lon': 76.91677815583232, 'altMeters': 0.0, 'nodeName': 'prasanth nagar', 'nodeType': 'None', 'popupText': 'prasanth nagar', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '1', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '1', 'elevMeters': None},
    {'id': 2, 'lat': 8.534228507902883, 'lon': 76.92895710345373, 'altMeters': 0.0, 'nodeName': 'chadrakumar panshop kochullor', 'nodeType': 'None', 'popupText': 'chadrakumar panshop kochullor', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '6', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '6', 'elevMeters': None},
    {'id': 3, 'lat': 8.53780581831055, 'lon': 76.91248572881265, 'altMeters': 0.0, 'nodeName': 'Cheruvikkal', 'nodeType': 'None', 'popupText': 'Cheruvikkal', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '8', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '8', 'elevMeters': None},
    {'id': 4, 'lat': 8.530538055280172, 'lon': 76.92078689585951, 'altMeters': 0.0, 'nodeName': 'Prasanna store', 'nodeType': 'None', 'popupText': 'Prasanna store', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '2', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '2', 'elevMeters': None},
    {'id': 5, 'lat': 8.53353861325879, 'lon': 76.92266693784279, 'altMeters': 0.0, 'nodeName': 'Priyadarshini nagar', 'nodeType': 'None', 'popupText': 'Priyadarshini nagar', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 6, 'lat':8.533353555768477, 'lon': 76.92906312274451, 'altMeters': 0.0, 'nodeName': 'Ullor', 'nodeType': 'None', 'popupText': 'Ullor', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 7, 'lat':8.521772798305816, 'lon':76.91325407290314, 'altMeters': 0.0, 'nodeName': 'govt care puliyarakottah', 'nodeType': 'None', 'popupText': 'govt care puliyarakottah', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 8, 'lat': 8.529350415410152, 'lon': 76.91216555538024, 'altMeters': 0.0, 'nodeName': 'Aditya storet', 'nodeType': 'None', 'popupText': 'Aditya storet', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    {'id': 9, 'lat': 8.5304234147535, 'lon': 76.91251194003772, 'altMeters': 0.0, 'nodeName': 'Sobhas Mini Supermarket', 'nodeType': 'None', 'popupText': 'Sobhas Mini Supermarket', 'leafletIconPrefix': 'glyphicon', 'leafletIconType': 'star', 'leafletColor': 'blue', 'leafletIconText': '7', 'cesiumIconType': 'pin', 'cesiumColor': 'blue', 'cesiumIconText': '7', 'elevMeters': None},
    ]
myNodes = pd.DataFrame(nodesArray)

# %%
[time, dist] = vrv.getTimeDist2D(nodes        = myNodes,
                                 matrixType   = 'all2all',
                                 routeType    = 'fastest',
                                 dataProvider = 'OSRM-online')

# %%
route = {}
truckNodes = myNodes

# Solve TSP using a simple nearest-neighbors heuristic
startNode = 0  # depot
route['truck'] = [startNode]
while (len(route['truck']) < len(truckNodes)):
    closestNode = vrv.nearestNodes(
        nodes=truckNodes[~truckNodes['id'].isin(route['truck'][0:-1])],
        origin=route['truck'][-1],
        costDict=dist,
        k=1
    )['id'].values[0]
    route['truck'].append(closestNode)

# Return to depot
route['truck'].append(startNode)
node_path = route['truck']
print(node_path)
# Out:
# [0, 3, 9, 8, 1, 4, 5, 6, 2, 7, 0]

# %%
dist_Meter = vrv.convertMatricesDictionaryToDataframe(dist)

# %%
total_distance_traveled = 0

# Iterate through the node path to calculate distances
for i in range(len(node_path) - 1):
    from_node = node_path[i]
    to_node = node_path[i + 1]
    distance = dist_Meter[from_node][to_node]
    total_distance_traveled += distance

distanceKilometers = vrv.convertDistance(total_distance_traveled, 'm', 'km')
distanceKilometers
# Out:
# 11.179200000000002

# %%
# Convert the truck's route to an "arcs" dataframe:
myArcs = vrv.createArcsFromNodeSeq(nodeSeq  = route['truck'],
                                   nodes    = myNodes,
                                   objectID = 'Truck')
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   arcs = arcs.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_createEntitiesFromList.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   arcs = arcs.append({
# ...

# %%
# Turn-by-turn road network travel for the truck:
myAssignments = vrv.createAssignmentsFromArcs2D(
        arcs             = myArcs[myArcs['objectID'] == 'Truck'],
        modelFile        = 'veroviz/models/ub_truck.gltf',
        routeType        = 'fastest',
        dataProvider     = 'OSRM-online',
        serviceTimeSec   = 30,
        ganttColor       = 'orange')
# Out:
# Message: The origin point (lat: 8.543664387156573, lon: 76.91519350400598) is 45.9 meters away from the road. You might find a gap between the origin point and the route.
# Message: The destination point (lat: 8.53780581831055, lon: 76.91248572881265) is 13.2 meters away from the road. You might find a gap between destination point and the route.
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assignments = assignments.append({
# /usr/local/lib/python3.10/dist-packages/veroviz/_getShapepoints.py:138: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   assignments = assignments.append({
# ...

# %%
myMap = vrv.addLeafletText(
                           text        = distanceKilometers,
                           fontColor   = 'black',
                           anchorPoint = myBoundingRegion[3])

# %%
vrv.createLeaflet(nodes = myNodes,
                  mapObject = myMap,
                  arcs  = myAssignments)
# Out:
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:48: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   tmpSubAssignment = pd.concat([tmpSubAssignment, collection.loc[i: i, :].copy()], ignore_index= True, sort=True)
# /usr/local/lib/python3.10/dist-packages/veroviz/_deconstructAssignments.py:59: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
# ...
