# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit-s-s/kmeans/blob/Collection_points/K_Means_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install veroviz --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 38.9 MB/s eta 0:00:00

# %%
# Import Important Libraries

import numpy as np
import pandas as pd
import veroviz as vrv
import folium
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading the Dataset

fort = pd.read_csv('/content/fort.csv')
kodungannor = pd.read_csv('/content/kodunganoor.csv')
mch = pd.read_csv('/content/mch.csv')
pangode = pd.read_csv('/content/pangode.csv')
pettah = pd.read_csv('/content/pettah.csv')
poojapura = pd.read_csv('/content/poojapura.csv')
poonthura = pd.read_csv('/content/poonthura.csv')
vattiyoorkavu = pd.read_csv('/content/vattiyoorkavu.csv')

# %% [markdown]
# **Clusturing**

# %%
a = fort.iloc[:,1:3].values
b = kodungannor.iloc[:,1:3].values
c = mch.iloc[:,1:3].values
d = pangode.iloc[:,1:3].values
e = pettah.iloc[:,1:3].values
f = poojapura.iloc[:,1:3].values
g = poonthura.iloc[:,1:3].values
h = vattiyoorkavu.iloc[:,1:3].values

# %%
data = [a,b,c,d,e,f,g,h]

for x in data:
    sse = []
    for i in range(1, 11):
        kmeans = KMeans(n_clusters=i, init='k-means++', n_init=10, random_state=0)
        kmeans.fit(x)
        sse.append(kmeans.inertia_)
    plt.plot(range(1, 11), sse)
    plt.title('The elbow method')
    plt.xlabel('Number of clusters')
    plt.ylabel('SSE')
    plt.show()

# %%
n_a = 5
n_b = 4
n_c = 6
n_d = 4
n_e = 4
n_f = 5
n_g = 5
n_h = 5

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = n_a
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(a)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(a[cluster_labels == i][:, 1], a[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of locations')
plt.legend()
plt.show()
n_of_a = cluster_centers
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = n_b
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(b)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(b[cluster_labels == i][:, 1], b[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of locations')
plt.legend()
plt.show()
n_of_b = cluster_centers
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = n_c
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(c)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(c[cluster_labels == i][:, 1], c[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of locations')
plt.legend()
plt.show()
n_of_c = cluster_centers
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = n_d
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(d)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(d[cluster_labels == i][:, 1], d[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of locations')
plt.legend()
plt.show()
n_of_d = cluster_centers
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = n_e
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(e)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(e[cluster_labels == i][:, 1], e[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of locations')
plt.legend()
plt.show()
n_of_e = cluster_centers
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = n_f
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(f)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(f[cluster_labels == i][:, 1], f[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of locations')
plt.legend()
plt.show()
n_of_f = cluster_centers
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = n_g
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(g)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(g[cluster_labels == i][:, 1], g[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of locations')
plt.legend()
plt.show()
n_of_g = cluster_centers
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# Specify the number of clusters and create a KMeans model
num_clusters = n_h
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(h)

# Get cluster labels and cluster centers
cluster_labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
for i in range(num_clusters):
    plt.scatter(h[cluster_labels == i][:, 1], h[cluster_labels == i][:, 0], label=f'Cluster {i + 1}')

plt.scatter(cluster_centers[:, 1], cluster_centers[:, 0], c='black', marker='x', s=100, label='Cluster Centers')  # Corrected line
plt.xlabel('Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('K-Means Clustering of locations')
plt.legend()
plt.show()
n_of_h = cluster_centers
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
n_clusters = [n_of_a,n_of_b,n_of_c,n_of_d,n_of_e,n_of_f,n_of_g,n_of_h]
n_clusters
# Out:
# [array([[ 8.50939128, 76.97964596],
#         [ 8.47285179, 76.96052637],
#         [ 8.53033287, 76.99002909],
#         [ 8.49951558, 76.95668409],
#         [ 8.49054953, 76.97639329]]),
#  array([[ 8.48876745, 76.93997709],
#         [ 8.52045488, 77.00067384],
#         [ 8.5041    , 76.91607   ],
#         [ 8.4625    , 76.93038   ]]),
#  array([[ 8.45387751, 76.97025392],
#         [ 8.52196742, 76.92961053],
#         [ 8.48580713, 76.96445268],
#         [ 8.44084447, 77.01462925],
#         [ 8.46999131, 76.98938988],
#         [ 8.45156808, 76.99425896]]),
#  array([[ 8.54656912, 76.9907518 ],
#         [ 8.50487026, 76.97771152],
#         [ 8.47756964, 76.95489991],
#         [ 8.55041172, 76.96833355]]),
#  array([[ 8.53096963, 76.9398177 ],
#         [ 8.53064639, 76.88480311],
#         [ 8.50027993, 76.94406219],
#         [ 8.52368332, 76.92703024]]),
#  array([[ 8.52901188, 76.91267068],
#         [ 8.55843494, 76.903867  ],
#         [ 8.55178293, 76.9192038 ],
# ...

# %%
nodesData = pd.read_csv("/content/sample.csv")

# %%
myNodes = pd.DataFrame(nodesData)

# %%
vrv.createLeaflet(nodes     = myNodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
[time, dist] = vrv.getTimeDist2D(nodes        = myNodes,
                                 matrixType   = 'all2all',
                                 routeType    = 'fastest',
                                 dataProvider = 'OSRM-online')

# %%
dist_Meter = vrv.convertMatricesDictionaryToDataframe(dist)

# %%
sns.heatmap(dist_Meter,linewidth=.5)
# Out:
# <Axes: >
